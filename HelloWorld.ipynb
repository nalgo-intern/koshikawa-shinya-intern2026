# %% [markdown]
# <a href="https://colab.research.google.com/github/nalgo-intern/koshikawa-shinya-intern2026/blob/feature/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hello = "hello"
world = "world"
print(f"{hello}, {world}.")
# Out:
# hello, world.
